# %%
######################### DATA NORMALIZATION ###############################

import os
import pandas as pd
import pickle
import numpy as np

def calcNormFactors(readcounts):

    library_size = readcounts.sum(axis = 0)
    norm_factor = library_size/np.median(library_size)
    return readcounts.div(norm_factor, axis = 1)

def calcCPM(readcounts):

    library_size = readcounts.sum(axis=0)
    cpm = readcounts.div(library_size, axis=1) * 1e6  # CPM normalization
    return cpm

def readcounts_norm(tis):

    attphe = pd.read_pickle('data/processed/attphe.pkl')
    
    readcounts = pd.read_pickle(f'./data/processed/expression/readcounts_all/{tis}')

    intersected_samples = set(readcounts.columns).intersection(attphe['samp_id'])

    attphe_filtered = attphe[attphe['samp_id'].isin(intersected_samples)]

    readcounts_filtered = readcounts[list(intersected_samples)]

    readcounts_tmm = calcNormFactors(readcounts_filtered)

    readcounts_cpm = calcCPM(readcounts_filtered)
    
    readcounts_log2cpm = np.log2(readcounts_cpm + 1)


    output_dir = "./data/processed/expression/readcounts_tmm_all/"
    
    os.makedirs(output_dir, exist_ok=True)

    readcounts_log2cpm.to_pickle(os.path.join(output_dir, tis)) 

    sample_counts_list.append ({
        'Tissue' : tis,
        'SampleCount': len(intersected_samples)

    })

    print(f'Normalized data saved for {tis}')

alltis = os.listdir('data/processed/expression/readcounts_all/')

sample_counts_list = []

for tis in alltis:
    readcounts_norm(tis)


global_sample_counts_df = pd.DataFrame(sample_counts_list)
global_sample_counts_df.to_csv('./data/processed/sample_counts.csv', index=False)
# Out:
# Normalized data saved for Brain-Hypothalamus.pkl
# Normalized data saved for Muscle-Skeletal.pkl
# Normalized data saved for Minor Salivary Gland.pkl
# Normalized data saved for Cervix-Ectocervix.pkl
# Normalized data saved for Cells-EBV-transformed lymphocytes.pkl
# Normalized data saved for Pituitary.pkl
# Normalized data saved for Stomach.pkl
# Normalized data saved for Nerve-Tibial.pkl
# Normalized data saved for Brain-Caudate (basal ganglia).pkl
# Normalized data saved for Prostate.pkl
# Normalized data saved for Ovary.pkl
# Normalized data saved for Brain-Hippocampus.pkl
# Normalized data saved for Thyroid.pkl
# Normalized data saved for Esophagus-Gastroesophageal Junction.pkl
# Normalized data saved for Kidney-Cortex.pkl
# Normalized data saved for Heart-Left Ventricle.pkl
# Normalized data saved for Brain-Substantia nigra.pkl
# Normalized data saved for Whole Blood.pkl
# Normalized data saved for Liver.pkl
# Normalized data saved for Bladder.pkl
# Normalized data saved for Brain-Cerebellum.pkl
# Normalized data saved for Cells-Cultured fibroblasts.pkl
# Normalized data saved for Kidney-Medulla.pkl
# Normalized data saved for Heart-Atrial Appendage.pkl
# Normalized data saved for Brain-Nucleus accumbens (basal ganglia).pkl
# Normalized data saved for Colon-Transverse.pkl
# Normalized data saved for Spleen.pkl
# Normalized data saved for Esophagus-Muscularis.pkl
# Normalized data saved for Skin-Not Sun Exposed (Suprapubic).pkl
# Normalized data saved for Cervix-Endocervix.pkl
# Normalized data saved for Brain-Spinal cord (cervical c-1).pkl
# Normalized data saved for Artery-Aorta.pkl
# Normalized data saved for Adipose-Visceral (Omentum).pkl
# Normalized data saved for Pancreas.pkl
# Normalized data saved for Small Intestine-Terminal Ileum.pkl
# Normalized data saved for Brain-Cerebellar Hemisphere.pkl
# Normalized data saved for Brain-Anterior cingulate cortex (BA24).pkl
# Normalized data saved for Lung.pkl
# Normalized data saved for Uterus.pkl
# Normalized data saved for Adipose-Subcutaneous.pkl
# Normalized data saved for Artery-Tibial.pkl
# Normalized data saved for Brain-Amygdala.pkl
# Normalized data saved for Brain-Frontal Cortex (BA9).pkl
# Normalized data saved for Breast-Mammary Tissue.pkl
# Normalized data saved for Artery-Coronary.pkl
# Normalized data saved for Testis.pkl
# Normalized data saved for Vagina.pkl
# Normalized data saved for Colon-Sigmoid.pkl
# Normalized data saved for Skin-Sun Exposed (Lower leg).pkl
# Normalized data saved for Brain-Putamen (basal ganglia).pkl
# Normalized data saved for Adrenal Gland.pkl
# Normalized data saved for Fallopian Tube.pkl
# Normalized data saved for Brain-Cortex.pkl
# Normalized data saved for Esophagus-Mucosa.pkl
